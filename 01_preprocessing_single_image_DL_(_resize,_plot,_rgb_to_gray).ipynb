# %%
# !wget 'https://img.freepik.com/free-vector/blue-sports-car-isolated-white-vector_53876-67354.jpg'
# Out:
# --2024-01-17 16:02:05--  https://img.freepik.com/free-vector/blue-sports-car-isolated-white-vector_53876-67354.jpg
# Resolving img.freepik.com (img.freepik.com)... 23.48.4.65, 23.48.4.97, 2600:1407:a800::1737:dd91, ...
# Connecting to img.freepik.com (img.freepik.com)|23.48.4.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37866 (37K) [image/jpeg]
# Saving to: ‘blue-sports-car-isolated-white-vector_53876-67354.jpg’
#
# blue-sports-car-iso 100%[===================>]  36.98K  --.-KB/s    in 0.1s
#
# 2024-01-17 16:02:05 (264 KB/s) - ‘blue-sports-car-isolated-white-vector_53876-67354.jpg’ saved [37866/37866]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/content/car.jpg')

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[251, 251, 251],
#         [207, 207, 207],
#         [196, 196, 196],
#         ...,
#         [199, 199, 199],
#         [199, 199, 199],
#         [199, 199, 199]],
#
#        [[251, 251, 251],
#         [206, 206, 206],
#         [195, 195, 195],
#         ...,
#         [199, 199, 199],
#         [199, 199, 199],
#         [199, 199, 199]],
#
#        [[250, 250, 250],
#         [206, 206, 206],
#         [195, 195, 195],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (470, 626, 3)

# %%
img_plot = plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img = Image.open('/content/car.jpg')
img_resize = img.resize((200,200))

# %%
img_resize.save('resiged_car.jpg')

# %%
img_res = mpimg.imread('/content/resiged_car.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
import cv2

# %%
img = cv2.imread('/content/resiged_car.jpg')

# %%
gray_img = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
gray_img
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [214, 201, 199, ..., 201, 201, 201],
#        [214, 200, 198, ..., 200, 200, 200],
#        [213, 199, 198, ..., 200, 200, 200]], dtype=uint8)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=200x200>
