# %%
import tensorflow as tf
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from tensorflow.keras.preprocessing.image import load_img,array_to_img

# %%
BASE_DIR = '/kaggle/input/weather-dataset/dataset/rainbow'

# %%
image_paths = []
for image_name in os.listdir(BASE_DIR):
    image_path = os.path.join(BASE_DIR,image_name)
    image_paths.append(image_path)

# %%
len(image_paths)
# Out:
# 232

# %%
plt.figure(figsize=(20,20))
temp_images = image_paths[:25]
index = 1

for image_path in temp_images:
    plt.subplot(5,5,index)
    img = load_img(image_path)
    img = np.array(img)
    plt.imshow(img)
    plt.axis('off')
    index +=1

# %% [markdown]
# **The bellow section is for specific data set not for a hole directory**

# %%
"""" 

from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.image import resize as tf_resize
import numpy as np
from tqdm import tqdm

# Assuming image_paths is a list of file paths to the images
image_paths = ['/kaggle/input/weather-dataset/dataset/rainbow']
target_shape = (128, 128)  # Define the target shape for resizing

# Function to load images, resize them, and convert them to numpy arrays
def load_and_resize_images(image_paths, target_shape):
    image_arrays = []
    for path in tqdm(image_paths):
        # Load image using load_img from Keras
        img = load_img(path)
        # Resize image to target shape
        resized_img = tf_resize(img_to_array(img), target_shape)
        # Append the resized image array to the list
        image_arrays.append(resized_img)
    return image_arrays

# Call the function with the list of image paths
train_images = load_and_resize_images(image_paths, target_shape)

# Convert the list of arrays to a single numpy array
train_images = np.array(train_images)

# Check the shape of the first image to confirm they all have the same shape
print("Shape of all images after resizing:", train_images.shape[1:])
# Out:
# 2024-02-04 05:51:56.121941: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-04 05:51:56.122119: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-04 05:51:56.296747: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[1], line 23
#      20     return image_arrays
#      22 # Call the function with the list of image paths
# ---> 23 train_images = load_and_resize_images(image_paths, target_shape)
#      25 # Convert the list of arrays to a single numpy array
#      26 train_images = np.array(train_images)
#
# Cell In[1], line 15, in load_and_resize_images(image_paths, target_shape)
#      12 image_arrays = []
#      13 for path in tqdm(image_paths):
#      14     # Load image using load_img from Keras
# ---> 15     img = load_img(path)
#      16     # Resize image to target shape
#      17     resized_img = tf_resize(img_to_array(img), target_shape)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# IsADirectoryError: [Errno 21] Is a directory: '/kaggle/input/weather-dataset/dataset/rainbow'

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tqdm import tqdm

# Define the directory path containing images
directory_path = "/kaggle/input/weather-dataset/dataset/rainbow"

# Function to load images, resize them, and convert them to numpy arrays
def load_and_resize_images(directory_path, target_shape):
    image_paths = [os.path.join(directory_path, file) for file in os.listdir(directory_path)]
    image_arrays = []
    for path in tqdm(image_paths):
        # Load image using load_img from Keras
        img = load_img(path)
        # Resize image to target shape
        resized_img = tf.image.resize(img_to_array(img), target_shape)
        # Append the resized image array to the list
        image_arrays.append(resized_img)
    return image_arrays

# Define the target shape for resizing
target_shape = (224, 224)

# Call the function with the directory path
train_images = load_and_resize_images(directory_path, target_shape)

# Convert the list of arrays to a single numpy array
train_images = np.array(train_images)

# Check the shape of the first image to confirm they all have the same shape
print("Shape of all images after resizing:", train_images.shape[1:])
# Out:
# 100%|██████████| 232/232 [00:02<00:00, 94.70it/s]
# Shape of all images after resizing: (224, 224, 3)

# %%
import matplotlib.pyplot as plt

# Function to visualize images
def visualize_images(images, num_images=5):
    # Randomly select num_images from the dataset
    selected_images = np.random.choice(images.shape[0], num_images, replace=False)
    
    # Plot the images
    fig, axes = plt.subplots(1, num_images, figsize=(15, 5))
    for i, idx in enumerate(selected_images):
        axes[i].imshow(images[idx].astype('uint8'))  # Convert to uint8 for imshow
        axes[i].axis('off')
        axes[i].set_title(f"Image {idx}")
    plt.show()

# Visualize the reshaped images
visualize_images(train_images)
